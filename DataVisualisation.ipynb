# %%
import glob
import shutil
import os
import random

import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

from config import TRIAN_DATA_FOLDER

# %%
from utils.images import visualise_some_images, get_images_sizes

# %% [markdown]
# ## Visualise a few examples of images

# %%
cwd = os.getcwd()
cwd_prt = "/".join(cwd.split("/")[:-1])
path_to_train_data = cwd_prt + TRIAN_DATA_FOLDER
visualise_some_images(path_to_train_data)

# %% [markdown]
# ## Get the median and mean images dimenssions

# %%
mean_width, mean_heights, median_width, median_heights = get_images_sizes(path_to_train_data)

# %%
print(f"Mean width : {round(mean_width)}")
print(f"Mean heights : {round(mean_heights)}")
print(f"Median width : {median_width}")
print(f"Median heights : {median_heights}")
# Out:
# Mean width : 525
# Mean heights : 490
# Median width : 512.0
# Median heights : 512.0
